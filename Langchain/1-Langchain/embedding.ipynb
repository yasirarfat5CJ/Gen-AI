# %%
import os 
from dotenv import load_dotenv
load_dotenv()  #  to load all the env variables
# Out:
# True

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path=".env", override=True)

# print("OPENAI:", os.getenv("OPENAI_API_KEY"))
# print("GEMINI:", os.getenv("GEMINI_API_KEY"))
# print("OLLAMA:", os.getenv("OLLAMA_API_KEY"))
# print("LANGCHAIN:", os.getenv("LANGCHAIN_API_KEY"))
# Out:
# True

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader('speech.txt')
docs=loader.load()

from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=10)
final_documents=text_splitter.split_documents(docs)
final_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Speech: Believe in Yourself and Keep Moving Forward'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Good morning respected teachers and my dear friends,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Today, I want to talk about something very simple yet very powerful — belief in oneself.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Many of us dream big. We want success, respect, a good career, and a meaningful life. But often,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='often, the biggest obstacle is not the world outside us — it is the doubt inside us. We ask'),
#  Document(metadata={'source': 'speech.txt'}, page_content='We ask ourselves: Am I good enough? Can I really do this?'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Let me tell you something important:'),
# ...

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# Gemini embeddings
embeddings = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001"
)

# # Test embedding
text = "Gemini embeddings convert text into vectors"
vector = embeddings.embed_query(text)

print("Embedding dimension:", len(vector))
print("First 10 values:", vector[:10])
# Out:
# Embedding dimension: 768
# First 10 values: [-0.00014299256, -0.033798, -0.0015195203, 0.015425446, 0.019627614, -6.374076e-05, -0.017174387, -0.0354862, 0.01608349, 0.046429746]

# %%
## Vector Embedding and Vector store 
# we use Vector store DB chorma

from langchain_community.vectorstores import Chroma

db=Chroma.from_documents(final_documents,embeddings)
db

# %%
query="So, believe in yourself when no one else does."
retreive_res=db.similarity_search(query)
retreive_res
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='So, believe in yourself when no one else does.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Today, I want to talk about something very simple yet very powerful — belief in oneself.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Speech: Believe in Yourself and Keep Moving Forward'),
#  Document(metadata={'source': 'speech.txt'}, page_content='often, the biggest obstacle is not the world outside us — it is the doubt inside us. We ask')]
