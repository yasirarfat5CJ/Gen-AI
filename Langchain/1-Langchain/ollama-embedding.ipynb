# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embedding=(
    OllamaEmbeddings(model="gemma:2b")
)
# Out:
# /tmp/ipykernel_21748/1461778175.py:2: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   OllamaEmbeddings(model="gemma:2b")

# %%
embedding
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1=embedding.embed_documents(
    [
        "Alpha is the first letter of Greek alphanet"
    ]
)
r1
# Out:
# [[-2.9026434421539307,
#   -1.0942914485931396,
#   -2.009255886077881,
#   -0.13926580548286438,
#   -1.2401331663131714,
#   -1.2508971691131592,
#   -2.0971550941467285,
#   -1.9837602376937866,
#   -0.41508930921554565,
#   0.8177074790000916,
#   -1.830141544342041,
#   0.1923796385526657,
#   0.7367234230041504,
#   0.2324216514825821,
#   -2.548236608505249,
#   2.917388677597046,
#   2.600339412689209,
#   -0.11876016855239868,
#   0.006381295155733824,
#   0.44402235746383667,
#   0.11525484174489975,
#   -1.6497578620910645,
#   0.7835479974746704,
#   1.1572587490081787,
#   -1.033679723739624,
#   0.17408280074596405,
#   -1.79331374168396,
#   -0.7530277371406555,
#   0.8079383969306946,
#   -0.26120656728744507,
#   -2.480214834213257,
#   0.7441913485527039,
#   1.278892993927002,
#   0.004354238044470549,
#   -1.4769549369812012,
#   1.0857425928115845,
#   -0.9666368365287781,
#   -0.05698918551206589,
#   2.063765287399292,
#   0.15086115896701813,
# ...

# %%
len(r1[0])
# Out:
# 2048
