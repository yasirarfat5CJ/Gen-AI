# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/yasirarfat18/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/yasirarfat18/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/yasirarfat18/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/yasirarfat18/nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/yasirarfat18/nltk_data...
# True

# %%
## Bag of words 
import pandas as pd

msgs = pd.read_csv('spam.csv', encoding='latin-1')  # use correct encoding for SMS dataset
msgs = msgs[['v1', 'v2']]  # the dataset usually has these columns: v1=label, v2=message
msgs.columns = ['label', 'message']  # rename for clarity

msgs.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
# nltk.download('stopwords')

# stemming = PorterStemmer()

wordlemmatize=WordNetLemmatizer()
corpus = []

for message in msgs['message']:
    review = re.sub('[^a-zA-Z]', ' ', message)
    review = review.lower()
    review = review.split()
    review = [wordlemmatize.lemmatize(word) for word in review if word not in stopwords.words('english')]
    corpus.append(' '.join(review))

corpus
# Out:
# ['go jurong point crazy available bugis n great world la e buffet cine got amore wat',
#  'ok lar joking wif u oni',
#  'free entry wkly comp win fa cup final tkts st may text fa receive entry question std txt rate c apply',
#  'u dun say early hor u c already say',
#  'nah think go usf life around though',
#  'freemsg hey darling week word back like fun still tb ok xxx std chgs send rcv',
#  'even brother like speak treat like aid patent',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press copy friend callertune',
#  'winner valued network customer selected receivea prize reward claim call claim code kl valid hour',
#  'mobile month u r entitled update latest colour mobile camera free call mobile update co free',
#  'gonna home soon want talk stuff anymore tonight k cried enough today',
#  'six chance win cash pound txt csh send cost p day day tsandcs apply reply hl info',
# ...

# %%
##Create an bag of words  model 
# import sys
# !{sys.executable} -m pip install scikit-learn


from sklearn.feature_extraction.text import CountVectorizer

cv=CountVectorizer(max_features=2000,binary=True)
x=cv.fit_transform(corpus).toarray()
x
cv.vocabulary_
# Out:
# {'go': np.int64(672),
#  'point': np.int64(1282),
#  'crazy': np.int64(367),
#  'available': np.int64(130),
#  'bugis': np.int64(230),
#  'great': np.int64(696),
#  'world': np.int64(1948),
#  'la': np.int64(893),
#  'cine': np.int64(299),
#  'got': np.int64(687),
#  'wat': np.int64(1880),
#  'ok': np.int64(1185),
#  'lar': np.int64(901),
#  'joking': np.int64(857),
#  'wif': np.int64(1917),
#  'oni': np.int64(1192),
#  'free': np.int64(619),
#  'entry': np.int64(512),
#  'wkly': np.int64(1935),
#  'comp': np.int64(329),
#  'win': np.int64(1921),
#  'cup': np.int64(380),
#  'final': np.int64(584),
#  'tkts': np.int64(1735),
#  'st': np.int64(1605),
#  'may': np.int64(1036),
#  'text': np.int64(1698),
#  'receive': np.int64(1364),
#  'question': np.int64(1331),
#  'std': np.int64(1617),
#  'txt': np.int64(1783),
#  'rate': np.int64(1346),
#  'apply': np.int64(88),
#  'dun': np.int64(474),
#  'say': np.int64(1454),
#  'early': np.int64(479),
#  'already': np.int64(62),
# ...

# %%
## N-Gram

## create a bag of words
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=300,binary=True,ngram_range=(2,3))
x=cv.fit_transform(corpus).toarray()
cv.vocabulary_
# Out:
# {'free entry': np.int64(86),
#  'rate apply': np.int64(209),
#  'claim call': np.int64(45),
#  'call claim': np.int64(16),
#  'claim code': np.int64(46),
#  'update latest': np.int64(269),
#  'free call': np.int64(84),
#  'call mobile': np.int64(27),
#  'chance win': np.int64(44),
#  'win cash': np.int64(293),
#  'txt word': np.int64(264),
#  'dont miss': np.int64(66),
#  'let know': np.int64(138),
#  'feel like': np.int64(80),
#  'anything lor': np.int64(5),
#  'call reply': np.int64(33),
#  'mobile free': np.int64(167),
#  'free camcorder': np.int64(85),
#  'please call': np.int64(193),
#  'lt gt': np.int64(152),
#  'missed call': np.int64(164),
#  'want go': np.int64(287),
#  'first time': np.int64(83),
#  'like lt': np.int64(140),
#  'like lt gt': np.int64(141),
#  'sm ac': np.int64(231),
#  'sorry call': np.int64(232),
#  'call later': np.int64(25),
#  'sorry call later': np.int64(233),
#  'awarded bonus': np.int64(11),
#  'prize call': np.int64(204),
# ...

# %%
## TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf=TfidfVectorizer(max_features=200,ngram_range=(2,2))
x=tfidf.fit_transform(corpus).toarray()
x
tfidf.vocabulary_
# Out:
# {'free entry': np.int64(55),
#  'rate apply': np.int64(135),
#  'claim call': np.int64(28),
#  'call claim': np.int64(8),
#  'claim code': np.int64(29),
#  'free call': np.int64(54),
#  'call mobile': np.int64(16),
#  'chance win': np.int64(27),
#  'txt word': np.int64(176),
#  'let know': np.int64(93),
#  'feel like': np.int64(52),
#  'call reply': np.int64(20),
#  'mobile free': np.int64(105),
#  'please call': np.int64(125),
#  'lt gt': np.int64(101),
#  'missed call': np.int64(103),
#  'want go': np.int64(191),
#  'first time': np.int64(53),
#  'like lt': np.int64(95),
#  'sm ac': np.int64(150),
#  'sorry call': np.int64(151),
#  'call later': np.int64(14),
#  'awarded bonus': np.int64(5),
#  'prize call': np.int64(131),
#  'ur awarded': np.int64(179),
#  'call free': np.int64(10),
#  'thats cool': np.int64(166),
#  'hi hi': np.int64(81),
#  'call customer': np.int64(9),
#  'customer service': np.int64(39),
#  'service representative': np.int64(147),
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print("TF-IDF Matrix:\n", x.toarray())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'toarray'
